# %% [markdown]
# #Silver Layer: Data Transformation and Cleaning
#
# The Silver Layer focuses on transforming and cleaning the raw data collected from the previous Bronze Layer. This phase involves processing the data to make it more structured and suitable for analysis. The goal of this layer is to prepare the data for deeper analysis and insights extraction in the subsequent layers of the project.

# %%
import pandas as pd
from pyspark.sql import SparkSession

# %%
# Read a Parquet file
df_spark_loaded = spark.read.format("parquet").load("/FileStore/tables/messi_raw_data_parquet")

# %% [markdown]
# In the cell above, we converted the data saved in Parquet format into a Spark DataFrame. During the testing phases of developing this MVP, I noticed that some data were duplicated. To address this issue from the beginning, I returned here in the begining of the data to remove duplicates. At the same time, I took the opportunity to rename the column 'id' as it is a reserved word in SQL.

# %%
df_spark_loaded = df_spark_loaded.withColumnRenamed("id", "id_event")

# %%
# Remove duplicates
df_spark_loaded = df_spark_loaded.dropDuplicates(["id_event"])

# %% [markdown]
# I created some temporary tables for testing purposes and have kept them registered here.

# %%
# Create a temporary table called "messi_temp_silver"
df_spark_loaded.createOrReplaceTempView("messi_temp_silver")

# %%
spark.sql("SHOW TABLES").show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | default|          messi_data|      false|
# |        |messi_cleaned_silver|       true|
# |        |   messi_temp_silver|       true|
# |        |  messi_temp_silver2|       true|
# |        |  messi_temp_silver3|       true|
# +--------+--------------------+-----------+

# %%
# %sql
SELECT * FROM messi_temp_silver WHERE player_name = 'Lionel Andrés Messi Cuccittini' LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_event</th><th>index</th><th>period</th><th>timestamp</th><th>minute</th><th>second</th><th>possession</th><th>duration</th><th>type_id</th><th>type_name</th><th>possession_team_id</th><th>possession_team_name</th><th>play_pattern_id</th><th>play_pattern_name</th><th>team_id</th><th>team_name</th><th>tactics_formation</th><th>location</th><th>player_id</th><th>player_name</th><th>position_id</th><th>position_name</th><th>pass_recipient_id</th><th>pass_recipient_name</th><th>pass_length</th><th>pass_angle</th><th>pass_height_id</th><th>pass_height_name</th><th>pass_end_location</th><th>pass_body_part_id</th><th>pass_body_part_name</th><th>pass_type_id</th><th>pass_type_name</th><th>carry_end_location</th><th>under_pressure</th><th>pass_outcome_id</th><th>pass_outcome_name</th><th>ball_receipt_outcome_id</th><th>ball_receipt_outcome_name</th><th>counterpress</th><th>dribble_outcome_id</th><th>dribble_outcome_name</th><th>foul_committed_advantage</th><th>foul_won_advantage</th><th>duel_type_id</th><th>duel_type_name</th><th>duel_outcome_id</th><th>duel_outcome_name</th><th>pass_aerial_won</th><th>pass_switch</th><th>pass_technique_id</th><th>pass_technique_name</th><th>pass_through_ball</th><th>clearance_body_part_id</th><th>clearance_body_part_name</th><th>clearance_left_foot</th><th>out</th><th>off_camera</th><th>pass_deflected</th><th>pass_cross</th><th>clearance_head</th><th>pass_outswinging</th><th>interception_outcome_id</th><th>interception_outcome_name</th><th>pass_assisted_shot_id</th><th>pass_shot_assist</th><th>shot_one_on_one</th><th>shot_statsbomb_xg</th><th>shot_end_location</th><th>shot_key_pass_id</th><th>shot_type_id</th><th>shot_type_name</th><th>shot_outcome_id</th><th>shot_outcome_name</th><th>shot_technique_id</th><th>shot_technique_name</th><th>shot_body_part_id</th><th>shot_body_part_name</th><th>goalkeeper_end_location</th><th>goalkeeper_position_id</th><th>goalkeeper_position_name</th><th>goalkeeper_type_id</th><th>goalkeeper_type_name</th><th>foul_won_defensive</th><th>foul_committed_card_id</th><th>foul_committed_card_name</th><th>shot_first_time</th><th>goalkeeper_body_part_id</th><th>goalkeeper_body_part_name</th><th>goalkeeper_outcome_id</th><th>goalkeeper_outcome_name</th><th>goalkeeper_technique_id</th><th>goalkeeper_technique_name</th><th>dribble_overrun</th><th>ball_recovery_offensive</th><th>pass_no_touch</th><th>clearance_right_foot</th><th>ball_recovery_recovery_failure</th><th>dribble_nutmeg</th><th>pass_cut_back</th><th>miscontrol_aerial_won</th><th>shot_open_goal</th><th>shot_aerial_won</th><th>clearance_aerial_won</th><th>bad_behaviour_card_id</th><th>bad_behaviour_card_name</th><th>substitution_outcome_id</th><th>substitution_outcome_name</th><th>substitution_replacement_id</th><th>substitution_replacement_name</th><th>pass_inswinging</th><th>foul_committed_offensive</th><th>foul_committed_type_id</th><th>foul_committed_type_name</th><th>50_50_outcome_id</th><th>50_50_outcome_name</th><th>pass_straight</th><th>pass_goal_assist</th><th>block_offensive</th><th>clearance_other</th><th>block_deflection</th><th>shot_deflected</th><th>injury_stoppage_in_chain</th><th>pass_miscommunication</th><th>foul_committed_penalty</th><th>foul_won_penalty</th><th>goalkeeper_punched_out</th><th>shot_saved_off_target</th><th>goalkeeper_shot_saved_off_target</th><th>shot_saved_to_post</th><th>goalkeeper_shot_saved_to_post</th><th>block_save_block</th><th>dribble_no_touch</th><th>shot_redirect</th><th>shot_follows_dribble</th><th>goalkeeper_success_in_play</th><th>goalkeeper_lost_in_play</th><th>half_start_late_video_start</th><th>player_off_permanent</th><th>goalkeeper_lost_out</th><th>half_end_early_video_end</th><th>goalkeeper_success_out</th><th>goalkeeper_saved_to_post</th></tr></thead><tbody><tr><td>0000b8bf-8a71-423e-b260-6a681e9f549d</td><td>653</td><td>1</td><td>00:14:09.711</td><td ...

# %%
spark.table("messi_temp_silver").printSchema()
# Out:
# root
#  |-- id_event: string (nullable = true)
#  |-- index: long (nullable = true)
#  |-- period: long (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- minute: long (nullable = true)
#  |-- second: long (nullable = true)
#  |-- possession: long (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- type_id: long (nullable = true)
#  |-- type_name: string (nullable = true)
#  |-- possession_team_id: long (nullable = true)
#  |-- possession_team_name: string (nullable = true)
#  |-- play_pattern_id: long (nullable = true)
#  |-- play_pattern_name: string (nullable = true)
#  |-- team_id: long (nullable = true)
#  |-- team_name: string (nullable = true)
#  |-- tactics_formation: double (nullable = true)
#  |-- location: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- player_id: double (nullable = true)
#  |-- player_name: string (nullable = true)
#  |-- position_id: double (nullable = true)
#  |-- position_name: string (nullable = true)
#  |-- pass_recipient_id: double (nullable = true)
#  |-- pass_recipient_name: string (nullable = true)
#  |-- pass_length: double (nullable = true)
#  |-- pass_angle: double (nullable = true)
#  |-- pass_height_id: double (nullable = true)
#  |-- pass_height_name: string (nullable = true)
#  |-- pass_end_location: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- pass_body_part_id: double (nullable = true)
#  |-- pass_body_part_name: string (nullable = true)
#  |-- pass_type_id: double (nullable = true)
#  |-- pass_type_name: string (nullable = true)
#  |-- carry_end_location: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- under_pressure: boolean (nullable = true)
#  |-- pass_outcome_id: double (nullable = true)
#  |-- pass_outcome_name: string (nullable = true)
#  |-- ball_receipt_outcome_id: double (nullable = true)
#  |-- ball_receipt_outcome_name: string (nullable = true)
#  |-- counterpress: boolean (nullable = true)
#  |-- dribble_outcome_id: double (nullable = true)
#  |-- dribble_outcome_name: string (nullable = true)
#  |-- foul_committed_advantage: boolean (nullable = true)
#  |-- foul_won_advantage: boolean (nullable = true)
#  |-- duel_type_id: double (nullable = true)
#  |-- duel_type_name: string (nullable = true)
#  |-- duel_outcome_id: double (nullable = true)
#  |-- duel_outcome_name: string (nullable = true)
#  |-- pass_aerial_won: boolean (nullable = true)
#  |-- pass_switch: boolean (nullable = true)
#  |-- pass_technique_id: double (nullable = true)
#  |-- pass_technique_name: string (nullable = true)
#  |-- pass_through_ball: boolean (nullable = true)
#  |-- clearance_body_part_id: double (nullable = true)
#  |-- clearance_body_part_name: string (nullable = true)
#  |-- clearance_left_foot: boolean (nullable = true)
#  |-- out: boolean (nullable = true)
#  |-- off_camera: boolean (nullable = true)
#  |-- pass_deflected: boolean (nullable = true)
#  |-- pass_cross: boolean (nullable = true)
#  |-- clearance_head: boolean (nullable = true)
#  |-- pass_outswinging: boolean (nullable = true)
#  |-- interception_outcome_id: double (nullable = true)
#  |-- interception_outcome_name: string (nullable = true)
#  |-- pass_assisted_shot_id: string (nullable = true)
#  |-- pass_shot_assist: boolean (nullable = true)
#  |-- shot_one_on_one: boolean (nullable = true)
#  |-- shot_statsbomb_xg: double (nullable = true)
#  |-- shot_end_location: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- shot_key_pass_id: string (nullable = true)
#  |-- shot_type_id: double (nullable = true)
#  |-- shot_type_name: string (nullable = true)
#  |-- shot_outcome_id: double (nullable = true)
#  |-- shot_outcome_name: string (nullable = true)
#  |-- shot_technique_id: double (nullable = true)
#  |-- shot_technique_name: string (nullable = true)
#  |-- shot_body_part_id: double (nullable = true)
#  |-- shot_body_part_name: string (nullable = true)
#  |-- goalkeeper_end_location: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- goalkeeper_position_id: double (nullable = true)
#  |-- goalkeeper_position_name: string (nullable = true)
#  |-- goalkeeper_type_id: double (nullable = true)
#  |-- goalkeeper_type_name: string (nullable = true)
#  |-- foul_won_defensive: boolean (nullable = true)
#  |-- foul_committed_card_id: double (nullable = true)
#  |-- foul_committed_card_name: string (nullable = true)
#  |-- shot_first_time: boolean (nullable = true)
#  |-- goalkeeper_body_part_id: double (nullable = true)
#  |-- goalkeeper_body_part_name: string (nullable = true)
#  |-- goalkeeper_outcome_id: double (nullable = true)
#  |-- goalkeeper_outcome_name: string (nullable = true)
#  |-- goalkeeper_technique_id: double (nullable = true)
#  |-- goalkeeper_technique_name: string (nullable = true)
#  |-- dribble_overrun: boolean (nullable = true)
#  |-- ball_recovery_offensive: boolean (nullable = true)
#  |-- pass_no_touch: boolean (nullable = true)
#  |-- clearance_right_foot: boolean (nullable = true)
#  |-- ball_recovery_recovery_failure: boolean (nullable = true)
#  |-- dribble_nutmeg: boolean (nullable = true)
#  |-- pass_cut_back: boolean (nullable = true)
#  |-- miscontrol_aerial_won: boolean (nullable = true)
#  |-- shot_open_goal: boolean (nullable = true)
#  |-- shot_aerial_won: boolean (nullable = true)
#  |-- clearance_aerial_won: boolean (nullable = true)
#  |-- bad_behaviour_card_id: double (nullable = true)
#  |-- bad_behaviour_card_name: string (nullable = true)
#  |-- substitution_outcome_id: double (nullable = true)
#  |-- substitution_outcome_name: string (nullable = true)
#  |-- substitution_replacement_id: double (nullable = true)
#  |-- substitution_replacement_name: string (nullable = true)
#  |-- pass_inswinging: boolean (nullable = true)
#  |-- foul_committed_offensive: boolean (nullable = true)
#  |-- foul_committed_type_id: double (nullable = true)
#  |-- foul_committed_type_name: string (nullable = true)
#  |-- 50_50_outcome_id: double (nullable = true)
#  |-- 50_50_outcome_name: string (nullable = true)
#  |-- pass_straight: boolean (nullable = true)
#  |-- pass_goal_assist: boolean (nullable = true)
#  |-- block_offensive: boolean (nullable = true)
#  |-- clearance_other: boolean (nullable = true)
#  |-- block_deflection: boolean (nullable = true)
#  |-- shot_deflected: boolean (nullable = true)
#  |-- injury_stoppage_in_chain: boolean (nullable = true)
#  |-- pass_miscommunication: boolean (nullable = true)
#  |-- foul_committed_penalty: boolean (nullable = true)
#  |-- foul_won_penalty: boolean (nullable = true)
#  |-- goalkeeper_punched_out: boolean (nullable = true)
#  |-- shot_saved_off_target: boolean (nullable = true)
#  |-- goalkeeper_shot_saved_off_target: boolean (nullable = true)
#  |-- shot_saved_to_post: boolean (nullable = true)
#  |-- goalkeeper_shot_saved_to_post: boolean (nullable = true)
#  |-- block_save_block: boolean (nullable = true)
#  |-- dribble_no_touch: boolean (nullable = true)
#  |-- shot_redirect: boolean (nullable = true)
#  |-- shot_follows_dribble: boolean (nullable = true)
#  |-- goalkeeper_success_in_play: boolean (nullable = true)
#  |-- goalkeeper_lost_in_play: boolean (nullable = true)
#  |-- half_start_late_video_start: boolean (nullable = true)
#  |-- player_off_permanent: boolean (nullable = true)
#  |-- goalkeeper_lost_out: boolean (nullable = true)
#  |-- half_end_early_video_end: boolean (nullable = true)
#  |-- goalkeeper_success_out: boolean (nullable = true)
#  |-- goalkeeper_saved_to_post: boolean (nullable = true)

# %% [markdown]
# I replaced **.describe().show()** and **.summary().show()** by saving the result into a DataFrames and presenting it in this format because the table has many columns, making it difficult to interpret the information visually.

# %%
# Loading data from a temporary table
df_table_columns = spark.sql("SHOW COLUMNS IN messi_temp_silver")

#shape
num_columns = df_table_columns.count()
num_rows = spark.sql("SELECT COUNT(*) AS count FROM messi_temp_silver").first()["count"]

print(f"Columns: {num_columns} x Rows: {num_rows}")
# Out:
# Columns: 143 x Rows: 1976777

# %%
# Visualizing all columns of this df
pd.set_option('display.max_columns', None)

# %%
# Statistics description
df_description = spark.table("messi_temp_silver").describe()
df_description = df_description.toPandas()

df_description
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>id_event</th>
#       <th>index</th>
#       <th>period</th>
#       <th>timestamp</th>
#       <th>minute</th>
#       <th>second</th>
#       <th>possession</th>
#       <th>duration</th>
#       <th>type_id</th>
#       <th>type_name</th>
#       <th>possession_team_id</th>
#       <th>possession_team_name</th>
#       <th>play_pattern_id</th>
#       <th>play_pattern_name</th>
#       <th>team_id</th>
#       <th>team_name</th>
#       <th>tactics_formation</th>
#       <th>player_id</th>
#       <th>player_name</th>
#       <th>position_id</th>
#       <th>position_name</th>
#       <th>pass_recipient_id</th>
#       <th>pass_recipient_name</th>
#       <th>pass_length</th>
#       <th>pass_angle</th>
#       <th>pass_height_id</th>
#       <th>pass_height_name</th>
#       <th>pass_body_part_id</th>
#       <th>pass_body_part_name</th>
#       <th>pass_type_id</th>
#       <th>pass_type_name</th>
#       <th>pass_outcome_id</th>
#       <th>pass_outcome_name</th>
#       <th>ball_receipt_outcome_id</th>
#       <th>ball_receipt_outcome_name</th>
#       <th>dribble_outcome_id</th>
#       <th>dribble_outcome_name</th>
#       <th>duel_type_id</th>
#       <th>duel_type_name</th>
#       <th>duel_outcome_id</th>
#       <th>duel_outcome_name</th>
#       <th>pass_technique_id</th>
#       <th>pass_technique_name</th>
#       <th>clearance_body_part_id</th>
#       <th>clearance_body_part_name</th>
#       <th>interception_outcome_id</th>
#       <th>interception_outcome_name</th>
#       <th>pass_assisted_shot_id</th>
#       <th>shot_statsbomb_xg</th>
#       <th>shot_key_pass_id</th>
#       <th>shot_type_id</th>
#       <th>shot_type_name</th>
#       <th>shot_outcome_id</th>
#       <th>shot_outcome_name</th>
#       <th>shot_technique_id</th>
#       <th>shot_technique_name</th>
#       <th>shot_body_part_id</th>
#       <th>shot_body_part_name</th>
#       <th>goalkeeper_position_id</th>
#       <th>goalkeeper_position_name</th>
#       <th>goalkeeper_type_id</th>
#       <th>goalkeeper_type_name</th>
#       <th>foul_committed_card_id</th>
#       <th>foul_committed_card_name</th>
#       <th>goalkeeper_body_part_id</th>
#       <th>goalkeeper_body_part_name</th>
#       <th>goalkeeper_outcome_id</th>
#       <th>goalkeeper_outcome_name</th>
#       <th>goalkeeper_technique_id</th>
#       <th>goalkeeper_technique_name</th>
#       <th>bad_behaviour_card_id</th>
#       <th>bad_behaviour_card_name</th>
#       <th>substitution_outcome_id</th>
#       <th>substitution_outcome_name</th>
#       <th>substitution_replacement_id</th>
#       <th>substitution_replacement_name</th>
#       <th>foul_committed_type_id</th>
#       <th>foul_committed_type_name</th>
#       <th>50_50_outcome_id</th>
#       <th>50_50_outcome_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>
td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>None</td>
#       <td>1111.383650187602</td>
#       <td>0.499984725961907</td>
#       <td>None</td>
#       <td>26.889945442483594</td>
#       <td>17.3833533494916</td>
#       <td>55.838345877925256</td>
#       <td>2.0130726331521753</td>
#       <td>11.814214968586986</td>
#       <td>None</td>
#       <td>179.95726340309403</td>
#       <td>None</td>
#       <td>2.212915593662428</td>
#       <td>None</td>
#       <td>193.2129927971178</td>
#       <td>None</td>
#       <td>7827.833301654504</td>
#       <td>8721.188664210928</td>
#       <td>None</td>
#       <td>7.09286246521311</td>
#       <td>None</td>
#       <td>8535.8468276135</td>
#       <td>None</td>
#       <td>13.976019099757082</td>
#       <td>1.5685432985668513</td>
#       <td>0.7780432611922886</td>
#       <td>None</td>
#       <td>4.564964609506957</td>
#       <td>None</td>
#       <td>1.9941188133784848</td>
#       <td>None</td>
#       <td>23.849013756428498</td>
#       <td>None</td>
#       <td>0.0</td>

# %%
# Statistics summary
df_summary = spark.table("messi_temp_silver").summary()
df_summary = df_summary.toPandas()

df_summary
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>id_event</th>
#       <th>index</th>
#       <th>period</th>
#       <th>timestamp</th>
#       <th>minute</th>
#       <th>second</th>
#       <th>possession</th>
#       <th>duration</th>
#       <th>type_id</th>
#       <th>type_name</th>
#       <th>possession_team_id</th>
#       <th>possession_team_name</th>
#       <th>play_pattern_id</th>
#       <th>play_pattern_name</th>
#       <th>team_id</th>
#       <th>team_name</th>
#       <th>tactics_formation</th>
#       <th>player_id</th>
#       <th>player_name</th>
#       <th>position_id</th>
#       <th>position_name</th>
#       <th>pass_recipient_id</th>
#       <th>pass_recipient_name</th>
#       <th>pass_length</th>
#       <th>pass_angle</th>
#       <th>pass_height_id</th>
#       <th>pass_height_name</th>
#       <th>pass_body_part_id</th>
#       <th>pass_body_part_name</th>
#       <th>pass_type_id</th>
#       <th>pass_type_name</th>
#       <th>pass_outcome_id</th>
#       <th>pass_outcome_name</th>
#       <th>ball_receipt_outcome_id</th>
#       <th>ball_receipt_outcome_name</th>
#       <th>dribble_outcome_id</th>
#       <th>dribble_outcome_name</th>
#       <th>duel_type_id</th>
#       <th>duel_type_name</th>
#       <th>duel_outcome_id</th>
#       <th>duel_outcome_name</th>
#       <th>pass_technique_id</th>
#       <th>pass_technique_name</th>
#       <th>clearance_body_part_id</th>
#       <th>clearance_body_part_name</th>
#       <th>interception_outcome_id</th>
#       <th>interception_outcome_name</th>
#       <th>pass_assisted_shot_id</th>
#       <th>shot_statsbomb_xg</th>
#       <th>shot_key_pass_id</th>
#       <th>shot_type_id</th>
#       <th>shot_type_name</th>
#       <th>shot_outcome_id</th>
#       <th>shot_outcome_name</th>
#       <th>shot_technique_id</th>
#       <th>shot_technique_name</th>
#       <th>shot_body_part_id</th>
    "shot_one_on_one", "id_event","index", "period", "minute", "possession", "possession_team_name", 
    "team_name", "dribble_outcome_name", "dribble_overrun", "dribble_nutmeg", "dribble_no_touch"
]

# Create a DataFrame with the selected columns
df_cleaned = df_spark_loaded.select(columns_to_keep)

# Rename more 2 columns
df_cleaned = df_cleaned.withColumnRenamed("index", "index_match")
df_cleaned = df_cleaned.withColumnRenamed("minute", "minute_match")

# %%
df_cleaned.write.mode("overwrite").parquet("/FileStore/tables/messi_silver_done.parquet")

# %%
# Save in a temporary table to validate
df_cleaned.createOrReplaceTempView("messi_temp_silver_done")

# %%
# Show the schema of the new dataframe
df_cleaned.printSchema()
# Out:
# root
#  |-- player_name: string (nullable = true)
#  |-- pass_recipient_name: string (nullable = true)
#  |-- pass_length: double (nullable = true)
#  |-- pass_deflected: boolean (nullable = true)
#  |-- pass_miscommunication: boolean (nullable = true)
#  |-- pass_cross: boolean (nullable = true)
#  |-- pass_type_name: string (nullable = true)
#  |-- pass_outcome_name: string (nullable = true)
#  |-- pass_technique_name: string (nullable = true)
#  |-- type_name: string (nullable = true)
#  |-- shot_outcome_name: string (nullable = true)
#  |-- pass_shot_assist: boolean (nullable = true)
#  |-- pass_goal_assist: boolean (nullable = true)
#  |-- shot_body_part_name: string (nullable = true)
#  |-- counterpress: boolean (nullable = true)
#  |-- shot_end_location: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- shot_aerial_won: boolean (nullable = true)
#  |-- shot_follows_dribble: boolean (nullable = true)
#  |-- shot_first_time: boolean (nullable = true)
#  |-- shot_open_goal: boolean (nullable = true)
#  |-- shot_statsbomb_xg: double (nullable = true)
#  |-- shot_deflected: boolean (nullable = true)
#  |-- shot_technique_name: string (nullable = true)
#  |-- shot_type_name: string (nullable = true)
#  |-- position_name: string (nullable = true)
#  |-- under_pressure: boolean (nullable = true)
#  |-- tactics_formation: double (nullable = true)
#  |-- 50_50_outcome_name: string (nullable = true)
#  |-- bad_behaviour_card_name: string (nullable = true)
#  |-- play_pattern_name: string (nullable = true)
#  |-- shot_one_on_one: boolean (nullable = true)
#  |-- id_event: string (nullable = true)
#  |-- index_match: long (nullable = true)
#  |-- period: long (nullable = true)
#  |-- minute_match: long (nullable = true)
#  |-- possession: long (nullable = true)
#  |-- possession_team_name: string (nullable = true)
#  |-- team_name: string (nullable = true)
#  |-- dribble_outcome_name: string (nullable = true)
#  |-- dribble_overrun: boolean (nullable = true)
#  |-- dribble_nutmeg: boolean (nullable = true)
#  |-- dribble_no_touch: boolean (nullable = true)

# %%
# Count columns and rows
num_columns_cleaned = len(df_cleaned.columns)
num_rows_cleaned = df_cleaned.count()

print(f"Columns: {num_columns} x Rows: {num_rows}")
# Out:
# Columns: 143 x Rows: 1976777

# %%
# Statistics description
df_description_cleaned = spark.table("messi_temp_silver_done").describe()
df_description_cleaned = df_description_cleaned.toPandas()

df_description_cleaned
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>player_name</th>
#       <th>pass_recipient_name</th>
#       <th>pass_length</th>
#       <th>pass_type_name</th>
#       <th>pass_outcome_name</th>
#       <th>pass_technique_name</th>
#       <th>type_name</th>
#       <th>shot_outcome_name</th>
#       <th>shot_body_part_name</th>
#       <th>shot_statsbomb_xg</th>
#       <th>shot_technique_name</th>
#       <th>shot_type_name</th>
#       <th>position_name</th>
#       <th>tactics_formation</th>
#       <th>50_50_outcome_name</th>
#       <th>bad_behaviour_card_name</th>
#       <th>play_pattern_name</th>
#       <th>id_event</th>
#       <th>index_match</th>
#       <th>period</th>
#       <th>minute_match</th>
#       <th>possession</th>
#       <th>possession_team_name</th>
#       <th>team_name</th>
#       <th>dribble_outcome_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>1970092</td>
#       <td>522301</td>
#       <td>552987</td>
#       <td>95287</td>
#       <td>98516</td>
#       <td>8125</td>
#       <td>1976777</td>
#       <td>12986</td>
#       <td>12986</td>
#       <td>12986</td>
#       <td>12986</td>
#       <td>12986</td>
#       <td>1970092</td>
#       <td>2016</td>
#       <td>708</td>
#       <td>524</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>1976777</td>
#       <td>23290</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>None</td>
#       <td>None</td>
#       <td>20.430384714027713</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>0.11525035715378873</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>3109.504464285714</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1897.436162500879</td>
#       <td>1.4960756827907244</td>
#       <td>44.52193090065293</td>
#       <td>93.46939336101138</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>None</td>
#       <td>None</td>
#       <td>13.976019099757082</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>0.15237382570140548</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>7827.833301654504</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1111.383650187602</td>
#       <td>0.499984725961907</td>
#       <td>26.889945442483594</td>
#       <td>55.838345877925256</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>min</td>
#       <td>Aarón Escandell Banacloche</td>
#       <td>Aarón Escandell Banacloche</td>
#       <td>0.0</td>
#       <td>Corner</td>
#       <td>Incomplete</td>
#       <td>Inswinging</td>
#       <td>50/50</td>
#       <td>Blocked</td>
#       <td>Head</td>
#       <td>1.8E-4</td>
#       <td>Backheel</td>
#       <td>Corner</td>
#       <td>Center Attacking Midfield</td>
#       <td>343.0</td>
#       <td>Lost</td>
#       <td>Red Card</td>
#       <td>From Corner</td>
#       <td>00000e28-2f19-491b-88b9-1d9077baf034</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>Albacete</td>
#       <td>Albacete</td>
#       <td>Complete</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>max</td>
#       <td>Šime Vrsaljko</td>
#       <td>Šime Vrsaljko</td>
#       <td>119.19941</td>
#       <td>Throw-in</td>
#       <td>Unknown</td>
#       <td>Through Ball</td>
#       <td>Tactical Shift</td>
#       <td>Wayward</td>
#       <td>Right Foot</td>
#       <td>0.99281865</td>
#       <td>Volley</td>
#       <td>Penalty</td>
#       <td>Substitute</td>
#       <td>42211.0</td>
#       <td>Won</td>
#       <td>Yellow Card</td>
#       <td>Regular Play</td>
#       <td>fffffd42-a5ff-48dd-a264-1f5e08ef04ef</td>
#       <td>4806</td>
#       <td>2</td>
#       <td>98</td>
#       <td>273</td>
#       <td>Xerez</td>
#       <td>Xerez</td>
#       <td>Incomplete</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Statistics Summary
df_summary_cleaned = spark.table("messi_temp_silver_done").summary()
df_summary_cleaned = df_summary_cleaned.toPandas()

df_summary_cleaned
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th